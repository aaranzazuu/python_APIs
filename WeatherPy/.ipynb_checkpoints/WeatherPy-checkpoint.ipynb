# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from pprint import pprint

# %%
# Import API key
from api_keys import weather_api_key

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
#Perform API Calls
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date_unix = []

#Perform a weather check on each city using a series of successive API calls.
url = "http://api.openweathermap.org/data/2.5/weather?"
for city in cities:
# Build query URL
    query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"
    # Get weather data
    weather_response = requests.get(query_url).json()
    pprint(weather_response)
    try:
        city_name.append(weather_response["name"])
        lat.append(weather_response["coord"]["lat"])
        lng.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        humidity.append(weather_response["main"]["humidity"])
        cloudiness.append(weather_response["clouds"]["all"])
        wind_speed.append(weather_response["wind"]["speed"])
        country.append(weather_response["sys"]["country"])
        date_unix.append(weather_response["sys"]["sunrise"])  
    except:
        city_name.append("NaN")
        lat.append("NaN")
        lng.append("NaN")
        max_temp.append("NaN")
        humidity.append("NaN")
        cloudiness.append("NaN")
        wind_speed.append("NaN")
        country.append("NaN")
        date_unix.append("NaN")
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1588987043,
#  'id': 6201424,
#  'main': {'feels_like': 57.13,
#           'grnd_level': 1013,
#           'humidity': 62,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 59.83,
#           'temp_max': 59.83,
#           'temp_min': 59.83},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ', 'sunrise': 1588967507, 'sunset': 1589002216},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 28, 'speed': 3.47}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -21.2, 'lon': -175.2},
#  'dt': 1588987043,
#  'id': 4032243,
#  'main': {'feels_like': 84.7,
#           'humidity': 83,
#           'pressure': 1014,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Vaini',
#  'sys': {'country': 'TO',
#          'id': 7285,
#          'sunrise': 1589047305,
#          'sunset': 1589087563,
#          'type': 1},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -35.17, 'lon': 173.17},
#  'dt': 1588987043,
#  'id': 2194098,
#  'main': {'feels_like': 61.54,
#           'grnd_level': 1022,
#           'humidity': 63,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 65.41,
#           'temp_max': 65.41,
#           'temp_min': 65.41},
#  'name': 'Ahipara',
#  'sys': {'country': 'NZ', 'sunrise': 1588965018, 'sunset': 1589002635},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 165, 'speed': 8.25}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 36.62, 'lon': 101.77},
#  'dt': 1588987043,
#  'id': 1788852,
#  'main': {'feels_like': 33.35,
#           'grnd_level': 779,
#           'humidity': 74,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': 38.32,
#           'temp_max': 38.32,
#           'temp_min': 38.32},
#  'name': 'Xining',
#  'sys': {'country': 'CN', 'sunrise': 1588975861, 'sunset': 1589026064},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 9, 'speed': 2.15}}
# {'base': 'stations',
#  'clouds': {'all': 83},
#  'cod': 200,
#  'coord': {'lat': 50.68, 'lon': 156.12},
#  'dt': 1588987031,
#  'id': 2121385,
#  'main': {'feels_like': 22.01,
#           'grnd_level': 997,
#           'humidity': 88,
#           'pressure': 998,
#           'sea_level': 998,
#           'temp': 34.47,
#           'temp_max': 34.47,
#           'temp_min': 34.47},
#  'name': "Severo-Kuril'sk",
#  'snow': {'1h': 0.13},
#  'sys': {'country': 'RU', 'sunrise': 1588960573, 'sunset': 1589015264},
#  'timezone': 39600,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 284, 'speed': 15.59}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 39.76, 'lon': -105.22},
#  'dt': 1588987044,
#  'id': 5423294,
#  'main': {'feels_like': 46.51,
#           'humidity': 30,
#           'pressure': 1018,
#           'temp': 57.97,
#           'temp_max': 62.01,
#           'temp_min': 48.99},
#  'name': 'Golden',
#  'sys': {'country': 'US',
#          'id': 3444,
#          'sunrise': 1588938756,
#          'sunset': 1588989725,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 48279,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1588987023,
#  'id': 6165406,
#  'main': {'feels_like': 23.11,
#           'humidity': 59,
#           'pressure': 1028,
#           'temp': 33.8,
#           'temp_max': 33.8,
#           'temp_min': 33.8},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'sunrise': 1588933929,
#          'sunset': 1588991020,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1588987044,
#  'id': 4020109,
#  'main': {'feels_like': 82.11,
#           'grnd_level': 1008,
#           'humidity': 74,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 81.63,
#           'temp_max': 81.63,
#           'temp_min': 81.63},
#  'name': 'Atuona',
#  'sys': {'country': 'PF', 'sunrise': 1588951284, 'sunset': 1588993426},
#  'timezone': -34200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 105, 'speed': 15.03}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 70.37, 'lon': 31.11},
#  'dt': 1588987044,
#  'id': 777019,
#  'main': {'feels_like': 26.42,
#           'grnd_level': 1006,
#           'humidity': 83,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 34.21,
#           'temp_max': 34.21,
#           'temp_min': 34.21},
#  'name': 'Vardø',
#  'sys': {'country': 'NO', 'sunrise': 1588980010, 'sunset': 1589055831},
#  'timezone': 7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 285, 'speed': 6.89}}
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1588987045,
#  'id': 1015776,
#  'main': {'feels_like': 61.09,
#           'humidity': 87,
#           'pressure': 1023,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1589001719,
#          'sunset': 1589039436,
#          'type': 1},
#  'timezone': 7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 3.36}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1588987045,
#  'id': 3833367,
#  'main': {'feels_like': 41.32,
#           'humidity': 75,
#           'pressure': 992,
#           'temp': 46.4,
#           'temp_max': 46.4,
#           'temp_min': 46.4},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1588939654,
#          'sunset': 1588971107,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 49.58, 'lon': 111.98},
#  'dt': 1588987045,
#  'id': 2021041,
#  'main': {'feels_like': 33.89,
#           'grnd_level': 906,
#           'humidity': 69,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 41.77,
#           'temp_max': 41.77,
#           'temp_min': 41.77},
#  'name': 'Kyra',
#  'sys': {'country': 'RU', 'sunrise': 1588971383, 'sunset': 1589025641},
#  'timezone': 32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 336, 'speed': 7.76}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -39.55, 'lon': 174.13},
#  'dt': 1588987046,
#  'id': 2187826,
#  'main': {'feels_like': 60.98,
#           'humidity': 76,
#           'pressure': 974,
#           'temp': 61.03,
#           'temp_max': 63,
#           'temp_min': 57.99},
#  'name': 'Manaia',
#  'sys': {'country': 'NZ',
#          'id': 2019899,
#          'sunrise': 1588965306,
#          'sunset': 1589001887,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 53, 'gust': 4, 'speed': 1.99}}
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 62.53, 'lon': 155.8},
#  'dt': 1588987046,
#  'id': 2122493,
#  'main': {'feels_like': 21,
#           'grnd_level': 945,
#           'humidity': 96,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 29.73,
#           'temp_max': 29.73,
#           'temp_min': 29.73},
#  'name': 'Omsukchan',
#  'sys': {'country': 'RU', 'sunrise': 1588956945, 'sunset': 1589019046},
#  'timezone': 39600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 19, 'speed': 8.37}}
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1588987046,
#  'id': 546105,
#  'main': {'feels_like': 34.56,
#           'humidity': 56,
#           'pressure': 1009,
#           'temp': 42.48,
#           'temp_max': 44.6,
#           'temp_min': 39},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 8926,
#          'sunrise': 1588988086,
#          'sunset': 1589047909,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 6.71}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -53.15, 'lon': -70.92},
#  'dt': 1588987046,
#  'id': 3874787,
#  'main': {'feels_like': 34.34,
#           'humidity': 86,
#           'pressure': 992,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'sunrise': 1588939910,
#          'sunset': 1588972108,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 19},
#  'cod': 200,
#  'coord': {'lat': -21.21, 'lon': -159.78},
#  'dt': 1588987047,
#  'id': 4035715,
#  'main': {'feels_like': 82.69,
#           'humidity': 74,
#           'pressure': 1016,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 7271,
#          'sunrise': 1588957179,
#          'sunset': 1588997491,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -37.62, 'lon': -73.65},
#  'dt': 1588987047,
#  'id': 3883457,
#  'main': {'feels_like': 56.03,
#           'grnd_level': 1004,
#           'humidity': 94,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 57.54,
#           'temp_max': 57.54,
#           'temp_min': 57.54},
#  'name': 'Lebu',
#  'sys': {'country': 'CL', 'sunrise': 1588938120, 'sunset': 1588975208},
#  'timezone': -14400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 352, 'speed': 5.91}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 5.38, 'lon': -52.95},
#  'dt': 1588987047,
#  'id': 3380290,
#  'main': {'feels_like': 81.09,
#           'grnd_level': 1015,
#           'humidity': 80,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 78.53,
#           'temp_max': 78.53,
#           'temp_min': 78.53},
#  'name': 'Sinnamary',
#  'sys': {'country': 'GF', 'sunrise': 1588929484, 'sunset': 1588973908},
#  'timezone': -10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 10.69}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.33},
#  'dt': 1588987047,
#  'id': 2075265,
#  'main': {'feels_like': 32.83,
#           'humidity': 92,
#           'pressure': 1029,
#           'temp': 39,
#           'temp_max': 39,
#           'temp_min': 39},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2003721,
#          'sunrise': 1588978741,
#          'sunset': 1589016675,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 86, 'speed': 5.99}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1588987048,
#  'id': 4030556,
#  'main': {'feels_like': 78.1,
#           'grnd_level': 1013,
#           'humidity': 69,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 76.06,
#           'temp_max': 76.06,
#           'temp_min': 76.06},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1588951388, 'sunset': 1588991374},
#  'timezone': -32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 5.88}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 78.22, 'lon': 15.64},
#  'dt': 1588987048,
#  'id': 2729907,
#  'main': {'feels_like': 14.34,
#           'humidity': 73,
#           'pressure': 1003,
#           'temp': 26.6,
#           'temp_max': 26.6,
#           'temp_min': 26.6},
#  'name': 'Longyearbyen',
#  'sys': {'country': 'SJ', 'id': 1663, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 22.89, 'lon': -109.91},
#  'dt': 1588987048,
#  'id': 3985710,
#  'main': {'feels_like': 74.7,
#           'humidity': 28,
#           'pressure': 1011,
#           'temp': 82.74,
#           'temp_max': 87.8,
#           'temp_min': 80.01},
#  'name': 'Cabo San Lucas',
#  'sys': {'country': 'MX',
#          'id': 7151,
#          'sunrise': 1588941725,
#          'sunset': 1588989008,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 14484,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 270, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.97, 'lon': 102.5},
#  'dt': 1588987048,
#  'id': 2022572,
#  'main': {'feels_like': 8.4,
#           'grnd_level': 1001,
#           'humidity': 95,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 25.34,
#           'temp_max': 25.34,
#           'temp_min': 25.34},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 157, 'speed': 21.94}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.6, 'lon': -124.16},
#  'dt': 1588987049,
#  'id': 5563839,
#  'main': {'feels_like': 50.94,
#           'humidity': 93,
#           'pressure': 1015,
#           'temp': 56.68,
#           'temp_max': 59,
#           'temp_min': 55.4},
#  'name': 'Fortuna',
#  'sys': {'country': 'US',
#          'id': 4127,
#          'sunrise': 1588943183,
#          'sunset': 1588994390,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 11265,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 290, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -24.79, 'lon': -50.01},
#  'dt': 1588987049,
#  'id': 3466704,
#  'main': {'feels_like': 44.87,
#           'grnd_level': 909,
#           'humidity': 92,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 47.84,
#           'temp_max': 47.84,
#           'temp_min': 47.84},
#  'name': 'Castro',
#  'sys': {'country': 'BR', 'sunrise': 1588931138, 'sunset': 1588970844},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 48, 'speed': 3.47}}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': -33.02, 'lon': 27.91},
#  'dt': 1588987049,
#  'id': 1006984,
#  'main': {'feels_like': 70.63,
#           'grnd_level': 1019,
#           'humidity': 72,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 69.35,
#           'temp_max': 69.35,
#           'temp_min': 69.35},
#  'name': 'East London',
#  'sys': {'country': 'ZA', 'sunrise': 1588999665, 'sunset': 1589037712},
#  'timezone': 7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 284, 'speed': 3.49}}
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1588986900,
#  'id': 3369157,
#  'main': {'feels_like': 58.19,
#           'humidity': 93,
#           'pressure': 1019,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'sunrise': 1589002042,
#          'sunset': 1589039890,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1.12}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.48, 'lon': -54.33},
#  'dt': 1588987041,
#  'id': 3440777,
#  'main': {'feels_like': 43.9,
#           'grnd_level': 1017,
#           'humidity': 87,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 48.4,
#           'temp_max': 48.4,
#           'temp_min': 48.4},
#  'name': 'Rocha',
#  'sys': {'country': 'UY', 'sunrise': 1588933125, 'sunset': 1588970930},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 338, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 66.04, 'lon': -17.34},
#  'dt': 1588987050,
#  'id': 2629833,
#  'main': {'feels_like': 27.01,
#           'humidity': 59,
#           'pressure': 1027,
#           'temp': 33.8,
#           'temp_max': 33.8,
#           'temp_min': 33.8},
#  'name': 'Husavik',
#  'sys': {'country': 'IS',
#          'id': 83,
#          'sunrise': 1588996357,
#          'sunset': 1589062740,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 19.35, 'lon': -90.72},
#  'dt': 1588987050,
#  'id': 3531177,
#  'main': {'feels_like': 88.12,
#           'humidity': 74,
#           'pressure': 1011,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Champotón',
#  'sys': {'country': 'MX',
#          'id': 7121,
#          'sunrise': 1588937433,
#          'sunset': 1588984089,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 11265,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.23},
#  'dt': 1588986971,
#  'id': 3366880,
#  'main': {'feels_like': 55.8,
#           'humidity': 79,
#           'pressure': 1018,
#           'temp': 60.01,
#           'temp_max': 60.01,
#           'temp_min': 60.01},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2003650,
#          'sunrise': 1589001901,
#          'sunset': 1589039642,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 82, 'speed': 9.4}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 38.8, 'lon': -9.45},
#  'dt': 1588987051,
#  'id': 2269142,
#  'main': {'feels_like': 56.03,
#           'humidity': 79,
#           'pressure': 1013,
#           'temp': 59.04,
#           'temp_max': 61,
#           'temp_min': 57},
#  'name': 'Colares',
#  'sys': {'country': 'PT',
#          'id': 2021330,
#          'sunrise': 1589002255,
#          'sunset': 1589053054,
#          'type': 3},
#  'timezone': 3600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 215, 'speed': 6.76}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -33.92, 'lon': 25.57},
#  'dt': 1588987034,
#  'id': 964420,
#  'main': {'feels_like': 62.49,
#           'humidity': 100,
#           'pressure': 1024,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'ZA',
#          'id': 1973,
#          'sunrise': 1589000324,
#          'sunset': 1589038176,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 9000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 3.36}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 48.93, 'lon': -125.55},
#  'dt': 1588986898,
#  'id': 6171633,
#  'main': {'feels_like': 65.03,
#           'humidity': 45,
#           'pressure': 1019,
#           'temp': 67.91,
#           'temp_max': 70,
#           'temp_min': 64.4},
#  'name': 'Ucluelet',
#  'sys': {'country': 'CA',
#          'id': 735,
#          'sunrise': 1588942150,
#          'sunset': 1588996090,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 19.73, 'lon': -155.09},
#  'dt': 1588987052,
#  'id': 5855927,
#  'main': {'feels_like': 72.75,
#           'humidity': 51,
#           'pressure': 1017,
#           'temp': 77.43,
#           'temp_max': 84.2,
#           'temp_min': 71.01},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 7881,
#          'sunrise': 1588952844,
#          'sunset': 1588999575,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 29.06, 'lon': -13.56},
#  'dt': 1588987052,
#  'id': 2510573,
#  'main': {'feels_like': 67.77,
#           'humidity': 77,
#           'pressure': 1018,
#           'temp': 66.2,
#           'temp_max': 66.2,
#           'temp_min': 66.2},
#  'name': 'Teguise',
#  'sys': {'country': 'ES',
#          'id': 2379,
#          'sunrise': 1589004378,
#          'sunset': 1589052905,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 27.98, 'lon': -114.06},
#  'dt': 1588987052,
#  'id': 4021858,
#  'main': {'feels_like': 64.38,
#           'grnd_level': 1011,
#           'humidity': 62,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 71.49,
#           'temp_max': 71.49,
#           'temp_min': 71.49},
#  'name': 'Guerrero Negro',
#  'sys': {'country': 'MX', 'sunrise': 1588942237, 'sunset': 1588990488},
#  'timezone': -21600,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 315, 'speed': 17}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 37.72, 'lon': -25.43},
#  'dt': 1588987052,
#  'id': 3372472,
#  'main': {'feels_like': 54.77,
#           'humidity': 93,
#           'pressure': 1018,
#           'temp': 59,
#           'temp_max': 59,
#           'temp_min': 59},
#  'name': 'Vila Franca do Campo',
#  'sys': {'country': 'PT',
#          'id': 6899,
#          'sunrise': 1589006229,
#          'sunset': 1589056750,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 4000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 300, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 14.3, 'lon': 44.38},
#  'dt': 1588987052,
#  'id': 69559,
#  'main': {'feels_like': 52.45,
#           'grnd_level': 746,
#           'humidity': 60,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 56.57,
#           'temp_max': 56.57,
#           'temp_min': 56.57},
#  'name': 'Yarim',
#  'sys': {'country': 'YE', 'sunrise': 1588991817, 'sunset': 1589037655},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 85, 'speed': 4.41}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -5.2, 'lon': -35.46},
#  'dt': 1588987033,
#  'id': 3386213,
#  'main': {'feels_like': 86.47,
#           'humidity': 88,
#           'pressure': 1014,
#           'temp': 78.8,
#           'temp_max': 78.8,
#           'temp_min': 78.8},
#  'name': 'Touros',
#  'sys': {'country': 'BR',
#          'id': 8452,
#          'sunrise': 1588926078,
#          'sunset': 1588968920,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 21.64, 'lon': 69.61},
#  'dt': 1588987053,
#  'id': 1259395,
#  'main': {'feels_like': 86.7,
#           'grnd_level': 1007,
#           'humidity': 84,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 80.02,
#           'temp_max': 80.02,
#           'temp_min': 80.02},
#  'name': 'Porbandar',
#  'sys': {'country': 'IN', 'sunrise': 1588985137, 'sunset': 1589032224},
#  'timezone': 19800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 265, 'speed': 6.26}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 39.05, 'lon': -27.98},
#  'dt': 1588987053,
#  'id': 3372964,
#  'main': {'feels_like': 53.2,
#           'grnd_level': 1012,
#           'humidity': 89,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 61.27,
#           'temp_max': 61.27,
#           'temp_min': 61.27},
#  'name': 'Lagoa',
#  'rain': {'1h': 0.21},
#  'sys': {'country': 'PT', 'sunrise': 1589006666, 'sunset': 1589057538},
#  'timezone': 0,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 284, 'speed': 18.84}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 22.29, 'lon': 114.16},
#  'dt': 1588986855,
#  'id': 1819729,
#  'main': {'feels_like': 88.32,
#           'humidity': 70,
#           'pressure': 1010,
#           'temp': 84.13,
#           'temp_max': 86,
#           'temp_min': 82.99},
#  'name': 'Hong Kong',
#  'sys': {'country': 'HK',
#          'id': 9154,
#          'sunrise': 1588974390,
#          'sunset': 1589021588,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 62.46, 'lon': -114.35},
#  'dt': 1588986933,
#  'id': 6185377,
#  'main': {'feels_like': 25.9,
#           'humidity': 64,
#           'pressure': 1037,
#           'temp': 37.4,
#           'temp_max': 37.4,
#           'temp_min': 37.4},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 1007,
#          'sunrise': 1588935458,
#          'sunset': 1588997406,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'gust': 18.34, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 22.08, 'lon': -159.32},
#  'dt': 1588987054,
#  'id': 5848280,
#  'main': {'feels_like': 70.77,
#           'humidity': 61,
#           'pressure': 1019,
#           'temp': 77.36,
#           'temp_max': 80.6,
#           'temp_min': 75},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 7873,
#          'sunrise': 1588953652,
#          'sunset': 1589000797,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 19.46}}
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': -2.02, 'lon': 147.27},
#  'dt': 1588987054,
#  'id': 2092164,
#  'main': {'feels_like': 93.24,
#           'grnd_level': 1010,
#           'humidity': 73,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 85.21,
#           'temp_max': 85.21,
#           'temp_min': 85.21},
#  'name': 'Lorengau',
#  'sys': {'country': 'PG', 'sunrise': 1588968385, 'sunset': 1589011700},
#  'timezone': 36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 97, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 16.78, 'lon': 94.73},
#  'dt': 1588987054,
#  'id': 1328421,
#  'main': {'feels_like': 89.55,
#           'grnd_level': 1008,
#           'humidity': 68,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 85.87,
#           'temp_max': 85.87,
#           'temp_min': 85.87},
#  'name': 'Pathein',
#  'sys': {'country': 'MM', 'sunrise': 1588979530, 'sunset': 1589025773},
#  'timezone': 23400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 303, 'speed': 10.92}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.6, 'lon': 168.33},
#  'dt': 1588987055,
#  'id': 2206939,
#  'main': {'feels_like': 52.61,
#           'grnd_level': 1014,
#           'humidity': 73,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 57.29,
#           'temp_max': 57.29,
#           'temp_min': 57.29},
#  'name': 'Bluff',
#  'sys': {'country': 'NZ', 'sunrise': 1588967700, 'sunset': 1589002277},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 15, 'speed': 7.85}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 45.62, 'lon': -61.35},
#  'dt': 1588987055,
#  'id': 6111867,
#  'main': {'feels_like': 31.23,
#           'humidity': 52,
#           'pressure': 1005,
#           'temp': 41.49,
#           'temp_max': 42.8,
#           'temp_min': 39},
#  'name': 'Port Hawkesbury',
#  'sys': {'country': 'CA',
#          'id': 876,
#          'sunrise': 1588927354,
#          'sunset': 1588980071,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 14484,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -20.41, 'lon': 57.7},
#  'dt': 1588987055,
#  'id': 934322,
#  'main': {'feels_like': 77.86,
#           'humidity': 94,
#           'pressure': 1015,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Mahébourg',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'sunrise': 1588991326,
#          'sunset': 1589031752,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 82},
#  'cod': 200,
#  'coord': {'lat': 17.48, 'lon': 103.46},
#  'dt': 1588987055,
#  'id': 1606350,
#  'main': {'feels_like': 94.78,
#           'grnd_level': 991,
#           'humidity': 54,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 90.21,
#           'temp_max': 90.21,
#           'temp_min': 90.21},
#  'name': 'Sawang Daen Din',
#  'sys': {'country': 'TH', 'sunrise': 1588977377, 'sunset': 1589023737},
#  'timezone': 25200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 225, 'speed': 6.6}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 66.15, 'lon': -65.71},
#  'dt': 1588987056,
#  'id': 6096551,
#  'main': {'feels_like': 24.49,
#           'grnd_level': 1024,
#           'humidity': 91,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 28.92,
#           'temp_max': 28.92,
#           'temp_min': 28.92},
#  'name': 'Pangnirtung',
#  'sys': {'country': 'CA', 'sunrise': 1588921694, 'sunset': 1588987823},
#  'timezone': -14400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 236, 'speed': 0.25}}
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 65.61, 'lon': -37.64},
#  'dt': 1588987056,
#  'id': 3424607,
#  'main': {'feels_like': 22.01,
#           'humidity': 86,
#           'pressure': 1030,
#           'temp': 28.4,
#           'temp_max': 28.4,
#           'temp_min': 28.4},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 81,
#          'sunrise': 1588915345,
#          'sunset': 1588980699,
#          'type': 1},
#  'timezone': -7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.68, 'lon': 177.92},
#  'dt': 1588987056,
#  'id': 2187393,
#  'main': {'feels_like': 62.28,
#           'humidity': 64,
#           'pressure': 1020,
#           'temp': 64,
#           'temp_max': 64,
#           'temp_min': 64},
#  'name': 'Manutuke',
#  'sys': {'country': 'NZ',
#          'id': 2011018,
#          'sunrise': 1588964287,
#          'sunset': 1589001086,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 158, 'gust': 7, 'speed': 4}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 31.61, 'lon': 34.76},
#  'dt': 1588987057,
#  'id': 293842,
#  'main': {'feels_like': 62.15,
#           'humidity': 76,
#           'pressure': 1004,
#           'temp': 62.82,
#           'temp_max': 64.99,
#           'temp_min': 60.01},
#  'name': 'Kiryat Gat',
#  'sys': {'country': 'IL',
#          'id': 2002441,
#          'sunrise': 1588992516,
#          'sunset': 1589041573,
#          'type': 3},
#  'timezone': 10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 262, 'gust': 4, 'speed': 4}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 9.23, 'lon': 29.83},
#  'dt': 1588987057,
#  'id': 377472,
#  'main': {'feels_like': 88.81,
#           'grnd_level': 963,
#           'humidity': 57,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 84.61,
#           'temp_max': 84.61,
#           'temp_min': 84.61},
#  'name': 'Bentiu',
#  'sys': {'country': 'SS', 'sunrise': 1588995713, 'sunset': 1589040743},
#  'timezone': 10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 191, 'speed': 4.09}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 20.78, 'lon': 97.03},
#  'dt': 1588987057,
#  'id': 1293960,
#  'main': {'feels_like': 74.89,
#           'grnd_level': 861,
#           'humidity': 53,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 74.07,
#           'temp_max': 74.07,
#           'temp_min': 74.07},
#  'name': 'Taunggyi',
#  'sys': {'country': 'MM', 'sunrise': 1588978635, 'sunset': 1589025565},
#  'timezone': 23400,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 269, 'speed': 1.77}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 43.54, 'lon': -5.66},
#  'dt': 1588987057,
#  'id': 3121424,
#  'main': {'feels_like': 58.78,
#           'humidity': 90,
#           'pressure': 1010,
#           'temp': 58.6,
#           'temp_max': 59,
#           'temp_min': 57.99},
#  'name': 'Gijón',
#  'sys': {'country': 'ES',
#          'id': 2010306,
#          'sunrise': 1589000662,
#          'sunset': 1589052829,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 143, 'speed': 2.82}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 29.37, 'lon': -94.97},
#  'dt': 1588987057,
#  'id': 4692856,
#  'main': {'feels_like': 68.92,
#           'humidity': 83,
#           'pressure': 1015,
#           'temp': 72.01,
#           'temp_max': 73,
#           'temp_min': 70},
#  'name': 'Galveston',
#  'rain': {'1h': 0.25},
#  'sys': {'country': 'US',
#          'id': 4231,
#          'sunrise': 1588937517,
#          'sunset': 1588986045,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 40, 'speed': 16.11}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 54.43, 'lon': 31.9},
#  'dt': 1588987058,
#  'id': 525426,
#  'main': {'feels_like': 36.34,
#           'grnd_level': 991,
#           'humidity': 69,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 42.66,
#           'temp_max': 42.66,
#           'temp_min': 42.66},
#  'name': 'Sobolevo',
#  'sys': {'country': 'RU', 'sunrise': 1588989467, 'sunset': 1589045995},
#  'timezone': 10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 325, 'speed': 5.19}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.28, 'lon': 169.85},
#  'dt': 1588987012,
#  'id': 2208248,
#  'main': {'feels_like': 55.62,
#           'humidity': 61,
#           'pressure': 1019,
#           'temp': 57.99,
#           'temp_max': 57.99,
#           'temp_min': 57.99},
#  'name': 'Kaitangata',
#  'sys': {'country': 'NZ',
#          'id': 2000217,
#          'sunrise': 1588967283,
#          'sunset': 1589001964,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'gust': 5.99, 'speed': 1.99}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 32.19, 'lon': 48.24},
#  'dt': 1588987058,
#  'id': 114593,
#  'main': {'feels_like': 71.76,
#           'grnd_level': 1002,
#           'humidity': 29,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 75.74,
#           'temp_max': 75.74,
#           'temp_min': 75.74},
#  'name': 'Susa',
#  'sys': {'country': 'IR', 'sunrise': 1588989219, 'sunset': 1589038400},
#  'timezone': 16200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 306, 'speed': 3.53}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 19.22, 'lon': -104.7},
#  'dt': 1588987058,
#  'id': 3985168,
#  'main': {'feels_like': 84.58,
#           'humidity': 69,
#           'pressure': 1010,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'San Patricio',
#  'sys': {'country': 'MX',
#          'id': 7166,
#          'sunrise': 1588940798,
#          'sunset': 1588987434,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 283, 'speed': 6.02}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 57.79, 'lon': -152.41},
#  'dt': 1588987059,
#  'id': 5866583,
#  'main': {'feels_like': 32.23,
#           'humidity': 87,
#           'pressure': 1017,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Saint Paul Harbor',
#  'sys': {'country': 'US',
#          'id': 7668,
#          'sunrise': 1588946387,
#          'sunset': 1589004746,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 9656,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 40, 'speed': 18.34}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -20.34, 'lon': 57.76},
#  'dt': 1588987059,
#  'id': 1106677,
#  'main': {'feels_like': 77.86,
#           'humidity': 94,
#           'pressure': 1015,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Bambous Virieux',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'sunrise': 1588991305,
#          'sunset': 1589031744,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 47.67, 'lon': -52.73},
#  'dt': 1588987059,
#  'id': 6167817,
#  'main': {'feels_like': 22.48,
#           'humidity': 92,
#           'pressure': 1001,
#           'temp': 34.99,
#           'temp_max': 37,
#           'temp_min': 33.01},
#  'name': 'Torbay',
#  'sys': {'country': 'CA',
#          'id': 998,
#          'sunrise': 1588924928,
#          'sunset': 1588978359,
#          'type': 1},
#  'timezone': -9000,
#  'visibility': 24140,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280, 'gust': 23.04, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 43.32, 'lon': 145.57},
#  'dt': 1588987059,
#  'id': 2128975,
#  'main': {'feels_like': 62.37,
#           'humidity': 24,
#           'pressure': 1008,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Nemuro',
#  'sys': {'country': 'JP',
#          'id': 7976,
#          'sunrise': 1588964431,
#          'sunset': 1589016470,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 43.75, 'lon': -81.72},
#  'dt': 1588987060,
#  'id': 5962442,
#  'main': {'feels_like': 19.78,
#           'humidity': 68,
#           'pressure': 1014,
#           'temp': 34.23,
#           'temp_max': 36,
#           'temp_min': 33.01},
#  'name': 'Goderich',
#  'sys': {'country': 'CA',
#          'id': 2008021,
#          'sunrise': 1588932541,
#          'sunset': 1588984661,
#          'type': 3},
#  'timezone': -14400,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 17.67}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 72.79, 'lon': -56.15},
#  'dt': 1588987060,
#  'id': 3418910,
#  'main': {'feels_like': 10.62,
#           'grnd_level': 1026,
#           'humidity': 90,
#           'pressure': 1026,
#           'sea_level': 1026,
#           'temp': 21.47,
#           'temp_max': 21.47,
#           'temp_min': 21.47},
#  'name': 'Upernavik',
#  'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0},
#  'timezone': -7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 6, 'speed': 10.25}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 5.41, 'lon': 100.34},
#  'dt': 1588987060,
#  'id': 1735106,
#  'main': {'feels_like': 91.18,
#           'humidity': 94,
#           'pressure': 1007,
#           'temp': 80.11,
#           'temp_max': 82.4,
#           'temp_min': 78.01},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 9429,
#          'sunrise': 1588979087,
#          'sunset': 1589023524,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 64.38, 'lon': -173.3},
#  'dt': 1588987060,
#  'id': 4031574,
#  'main': {'feels_like': 30.43,
#           'grnd_level': 1005,
#           'humidity': 62,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 43.41,
#           'temp_max': 43.41,
#           'temp_min': 43.41},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU', 'sunrise': 1589034774, 'sunset': 1589099182},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 50, 'speed': 16.51}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -32.88, 'lon': -68.8},
#  'dt': 1588987061,
#  'id': 3864299,
#  'main': {'feels_like': 50.77,
#           'humidity': 71,
#           'pressure': 1010,
#           'temp': 53.6,
#           'temp_max': 53.6,
#           'temp_min': 53.6},
#  'name': 'Bermejo',
#  'sys': {'country': 'AR',
#          'id': 8238,
#          'sunrise': 1588936429,
#          'sunset': 1588974572,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
# ...
#  'timezone': 25200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 244, 'speed': 7.31}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 14.55, 'lon': -60.84},
#  'dt': 1588987182,
#  'id': 3570392,
#  'main': {'feels_like': 80.71,
#           'humidity': 78,
#           'pressure': 1018,
#           'temp': 79.3,
#           'temp_max': 80.6,
#           'temp_min': 78.01},
#  'name': 'Le Vauclin',
#  'sys': {'country': 'MQ',
#          'id': 8779,
#          'sunrise': 1588930663,
#          'sunset': 1588976516,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -19.06, 'lon': -169.92},
#  'dt': 1588986945,
#  'id': 4036284,
#  'main': {'feels_like': 87.37,
#           'humidity': 74,
#           'pressure': 1014,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Alofi',
#  'sys': {'country': 'NU',
#          'id': 7306,
#          'sunrise': 1588959433,
#          'sunset': 1589000104,
#          'type': 1},
#  'timezone': -39600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -45.58, 'lon': -72.07},
#  'dt': 1588987182,
#  'id': 3894426,
#  'main': {'feels_like': 43.97,
#           'humidity': 100,
#           'pressure': 995,
#           'temp': 46.4,
#           'temp_max': 46.4,
#           'temp_min': 46.4},
#  'name': 'Coyhaique',
#  'sys': {'country': 'CL',
#          'id': 8491,
#          'sunrise': 1588938810,
#          'sunset': 1588973760,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 500,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'},
#              {'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 304, 'speed': 2.82}}
# {'base': 'stations',
#  'clouds': {'all': 83},
#  'cod': 200,
#  'coord': {'lat': 30.44, 'lon': -84.28},
#  'dt': 1588987051,
#  'id': 4174715,
#  'main': {'feels_like': 72.88,
#           'humidity': 78,
#           'pressure': 1012,
#           'temp': 71.01,
#           'temp_max': 71.01,
#           'temp_min': 71.01},
#  'name': 'Tallahassee',
#  'sys': {'country': 'US',
#          'id': 2006015,
#          'sunrise': 1588934841,
#          'sunset': 1588983589,
#          'type': 3},
#  'timezone': -14400,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 219, 'speed': 5.14}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -22.12, 'lon': 14.28},
#  'dt': 1588987183,
#  'id': 3356832,
#  'main': {'feels_like': 64.29,
#           'grnd_level': 1013,
#           'humidity': 52,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 68.38,
#           'temp_max': 68.38,
#           'temp_min': 68.38},
#  'name': 'Henties Bay',
#  'sys': {'country': 'NA', 'sunrise': 1589001896, 'sunset': 1589042023},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 162, 'speed': 7.43}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -13.73, 'lon': 15.07},
#  'dt': 1588987183,
#  'id': 3351380,
#  'main': {'feels_like': 50.36,
#           'grnd_level': 834,
#           'humidity': 74,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 53.44,
#           'temp_max': 53.44,
#           'temp_min': 53.44},
#  'name': 'Caconda',
#  'sys': {'country': 'AO', 'sunrise': 1589001013, 'sunset': 1589042527},
#  'timezone': 3600,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 70, 'speed': 3.53}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41, 'lon': -115.5},
#  'dt': 1588987184,
#  'id': 5703673,
#  'main': {'feels_like': 58.55,
#           'humidity': 8,
#           'pressure': 1018,
#           'temp': 70.95,
#           'temp_max': 77,
#           'temp_min': 61},
#  'name': 'Elko',
#  'sys': {'country': 'US',
#          'id': 3961,
#          'sunrise': 1588941050,
#          'sunset': 1588992366,
#          'type': 1},
#  'timezone': -25200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 40.13, 'lon': 63.45},
#  'dt': 1588987184,
#  'id': 1513990,
#  'main': {'feels_like': 63.54,
#           'grnd_level': 989,
#           'humidity': 56,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 68.5,
#           'temp_max': 68.5,
#           'temp_min': 68.5},
#  'name': 'Gazli',
#  'sys': {'country': 'UZ', 'sunrise': 1588984591, 'sunset': 1589035727},
#  'timezone': 18000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 244, 'speed': 10.04}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 66.77, 'lon': 123.37},
#  'dt': 1588987184,
#  'id': 2012530,
#  'main': {'feels_like': 6.73,
#           'grnd_level': 1008,
#           'humidity': 93,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 18.57,
#           'temp_max': 18.57,
#           'temp_min': 18.57},
#  'name': 'Zhigansk',
#  'sys': {'country': 'RU', 'sunrise': 1588962133, 'sunset': 1589029424},
#  'timezone': 32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 333, 'speed': 11.65}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 58.83, 'lon': 44.32},
#  'dt': 1588987185,
#  'id': 546282,
#  'main': {'feels_like': 41.11,
#           'grnd_level': 996,
#           'humidity': 90,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 46.38,
#           'temp_max': 46.38,
#           'temp_min': 46.38},
#  'name': 'Kologriv',
#  'sys': {'country': 'RU', 'sunrise': 1588985160, 'sunset': 1589044341},
#  'timezone': 10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 13, 'speed': 6.73}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 4.12, 'lon': 43.89},
#  'dt': 1588987185,
#  'id': 49747,
#  'main': {'feels_like': 74.55,
#           'grnd_level': 955,
#           'humidity': 81,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 74.5,
#           'temp_max': 74.5,
#           'temp_min': 74.5},
#  'name': 'Oddur',
#  'sys': {'country': 'SO', 'sunrise': 1588992732, 'sunset': 1589036974},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 212, 'speed': 11.95}}
# {'base': 'stations',
#  'clouds': {'all': 30},
#  'cod': 200,
#  'coord': {'lat': 41.77, 'lon': 34.87},
#  'dt': 1588987185,
#  'id': 739598,
#  'main': {'feels_like': 36.16,
#           'grnd_level': 949,
#           'humidity': 86,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 40.98,
#           'temp_max': 40.98,
#           'temp_min': 40.98},
#  'name': 'Sinop Province',
#  'sys': {'country': 'TR', 'sunrise': 1588991211, 'sunset': 1589042825},
#  'timezone': 10800,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 214, 'speed': 3.67}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 15.13, 'lon': -23.22},
#  'dt': 1588986963,
#  'id': 3374120,
#  'main': {'feels_like': 68.61,
#           'humidity': 69,
#           'pressure': 1017,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Vila do Maio',
#  'sys': {'country': 'CV',
#          'id': 2462,
#          'sunrise': 1589007969,
#          'sunset': 1589053950,
#          'type': 1},
#  'timezone': -3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -8.38, 'lon': -74.55},
#  'dt': 1588987186,
#  'id': 3693345,
#  'main': {'feels_like': 76.46,
#           'humidity': 73,
#           'pressure': 1018,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Pucallpa',
#  'sys': {'country': 'PE',
#          'id': 8675,
#          'sunrise': 1588935699,
#          'sunset': 1588978061,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 3.36}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 31.22, 'lon': 29.96},
#  'dt': 1588987186,
#  'id': 361058,
#  'main': {'feels_like': 61.23,
#           'humidity': 82,
#           'pressure': 1011,
#           'temp': 66.2,
#           'temp_max': 66.2,
#           'temp_min': 66.2},
#  'name': 'Alexandria',
#  'sys': {'country': 'EG',
#          'id': 2511,
#          'sunrise': 1588993710,
#          'sunset': 1589042683,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'speed': 14.99}}
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': -20.74, 'lon': 116.85},
#  'dt': 1588987186,
#  'id': 6620339,
#  'main': {'feels_like': 66.07,
#           'grnd_level': 1012,
#           'humidity': 27,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 80.51,
#           'temp_max': 80.51,
#           'temp_min': 80.51},
#  'name': 'Karratha',
#  'sys': {'country': 'AU', 'sunrise': 1588977154, 'sunset': 1589017533},
#  'timezone': 28800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 93, 'speed': 22.95}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.47, 'lon': 166.1},
#  'dt': 1588987187,
#  'id': 2120591,
#  'main': {'feels_like': 15.85,
#           'grnd_level': 970,
#           'humidity': 97,
#           'pressure': 999,
#           'sea_level': 999,
#           'temp': 27.45,
#           'temp_max': 27.45,
#           'temp_min': 27.45},
#  'name': 'Tilichiki',
#  'sys': {'country': 'RU', 'sunrise': 1588955371, 'sunset': 1589015676},
#  'timezone': 43200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 11, 'speed': 13}}
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': -6.98, 'lon': -34.83},
#  'dt': 1588987187,
#  'id': 3404558,
#  'main': {'feels_like': 80.71,
#           'humidity': 94,
#           'pressure': 1015,
#           'temp': 75.2,
#           'temp_max': 75.2,
#           'temp_min': 75.2},
#  'name': 'Cabedelo',
#  'sys': {'country': 'BR',
#          'id': 8391,
#          'sunrise': 1588926060,
#          'sunset': 1588968635,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 69.3, 'lon': 139.9},
#  'dt': 1588987187,
#  'id': 2028164,
#  'main': {'feels_like': 20.34,
#           'grnd_level': 941,
#           'humidity': 98,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 27.03,
#           'temp_max': 27.03,
#           'temp_min': 27.03},
#  'name': 'Deputatsky',
#  'sys': {'country': 'RU', 'sunrise': 1588955669, 'sunset': 1589027953},
#  'timezone': 36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 106, 'speed': 4.25}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 20.7, 'lon': -105.2},
#  'dt': 1588987187,
#  'id': 4004293,
#  'main': {'feels_like': 85.3,
#           'humidity': 83,
#           'pressure': 1011,
#           'temp': 80.31,
#           'temp_max': 80.6,
#           'temp_min': 80.01},
#  'name': 'Ixtapa',
#  'sys': {'country': 'MX',
#          'id': 7156,
#          'sunrise': 1588940790,
#          'sunset': 1588987682,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 24140,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 230, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 13},
#  'cod': 200,
#  'coord': {'lat': 20.93, 'lon': -17.03},
#  'dt': 1588987188,
#  'id': 2377457,
#  'main': {'feels_like': 57.33,
#           'humidity': 82,
#           'pressure': 1015,
#           'temp': 66.2,
#           'temp_max': 66.2,
#           'temp_min': 66.2},
#  'name': 'Nouadhibou',
#  'sys': {'country': 'MR',
#          'id': 2444,
#          'sunrise': 1589005987,
#          'sunset': 1589052961,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 21.92}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.79, 'lon': 100.97},
#  'dt': 1588987188,
#  'id': 1794209,
#  'main': {'feels_like': 77.58,
#           'grnd_level': 871,
#           'humidity': 67,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 74.55,
#           'temp_max': 74.55,
#           'temp_min': 74.55},
#  'name': 'Simao',
#  'sys': {'country': 'CN', 'sunrise': 1588977509, 'sunset': 1589024800},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 203, 'speed': 2.42}}
# {'base': 'stations',
#  'clouds': {'all': 17},
#  'cod': 200,
#  'coord': {'lat': 19.21, 'lon': -69.34},
#  'dt': 1588987188,
#  'id': 3492997,
#  'main': {'feels_like': 83.28,
#           'grnd_level': 1012,
#           'humidity': 82,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 78.48,
#           'temp_max': 78.48,
#           'temp_min': 78.48},
#  'name': 'Samaná',
#  'sys': {'country': 'DO', 'sunrise': 1588932315, 'sunset': 1588978944},
#  'timezone': -14400,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 148, 'speed': 7.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 26.55, 'lon': 82.65},
#  'dt': 1588987188,
#  'id': 1255024,
#  'main': {'feels_like': 78.48,
#           'grnd_level': 997,
#           'humidity': 27,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 83.16,
#           'temp_max': 83.16,
#           'temp_min': 83.16},
#  'name': 'Tāndā',
#  'sys': {'country': 'IN', 'sunrise': 1588981550, 'sunset': 1589029553},
#  'timezone': 19800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 107, 'speed': 6.51}}

# %% [markdown]
# #Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
len(country)
# Out:
# 617

# %%
weather = pd.DataFrame({"City": city_name, "Lat": lat, "Lng" : lng, "Max Temp": max_temp, "Humidity": humidity,
                        "Cloudiness": cloudiness, "Wind Speed": wind_speed, 
                        "Country": country, "Date": date_unix})
weather
# Out:
#                 City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0            Mataura -46.19  168.86    59.83       62          0       3.47
# 1              Vaini  -21.2  -175.2     82.4       83         75      16.11
# 2            Ahipara -35.17  173.17    65.41       63          0       8.25
# 3             Xining  36.62  101.77    38.32       74         92       2.15
# 4    Severo-Kuril'sk  50.68  156.12    34.47       88         83      15.59
# ..               ...    ...     ...      ...      ...        ...        ...
# 588           Ixtapa   20.7  -105.2     80.6       83          5       9.17
# 589       Nouadhibou  20.93  -17.03     66.2       82         13      21.92
# 590            Simao  22.79  100.97    74.55       67          0       2.42
# 591           Samaná  19.21  -69.34    78.48       82         17       7.36
# 592            Tāndā  26.55   82.65    83.16       27          0       6.51
#
#     Country        Date
# 0        NZ  1588967507
# 1        TO  1589047305
# 2        NZ  1588965018
# 3        CN  1588975861
# 4        RU  1588960573
# ..      ...         ...
# 588      MX  1588940790
# 589      MR  1589005987
# 590      CN  1588977509
# 591      DO  1588932315
# 592      IN  1588981550
#
# [593 rows x 9 columns]

# %%
#Print CSV with df
weather.to_csv("output_data/cities.csv", index = False)

# %%
#Read CSV File
file = "output_data/cities.csv"
weather_df = pd.read_csv(file)

weather_clean = weather_df.dropna(how="all")

weather_clean.reset_index()
# Out:
#      index             City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        0          Mataura -46.19  168.86     59.83      62.0         0.0
# 1        1            Vaini -21.20 -175.20     82.40      83.0        75.0
# 2        2          Ahipara -35.17  173.17     65.41      63.0         0.0
# 3        3           Xining  36.62  101.77     38.32      74.0        92.0
# 4        4  Severo-Kuril'sk  50.68  156.12     34.47      88.0        83.0
# ..     ...              ...    ...     ...       ...       ...         ...
# 536    588           Ixtapa  20.70 -105.20     80.60      83.0         5.0
# 537    589       Nouadhibou  20.93  -17.03     66.20      82.0        13.0
# 538    590            Simao  22.79  100.97     74.55      67.0         0.0
# 539    591           Samaná  19.21  -69.34     78.48      82.0        17.0
# 540    592            Tāndā  26.55   82.65     83.16      27.0         0.0
#
#      Wind Speed Country          Date
# 0          3.47      NZ  1.588968e+09
# 1         16.11      TO  1.589047e+09
# 2          8.25      NZ  1.588965e+09
# 3          2.15      CN  1.588976e+09
# 4         15.59      RU  1.588961e+09
# ..          ...     ...           ...
# 536        9.17      MX  1.588941e+09
# 537       21.92      MR  1.589006e+09
# 538        2.42      CN  1.588978e+09
# 539        7.36      DO  1.588932e+09
# 540        6.51      IN  1.588982e+09
#
# [541 rows x 10 columns]

# %%
weather_clean.count()
# Out:
# City          541
# Lat           541
# Lng           541
# Max Temp      541
# Humidity      541
# Cloudiness    541
# Wind Speed    541
# Country       535
# Date          541
# dtype: int64

# %%
#Inspect the data and remove the cities where the humidity > 100%.
weather_clean.loc[weather_clean["Humidity"]>100, :]

#Skipped this step because there are no cities that have humidity > 100%.
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#Print CSV with df
weather_clean.to_csv("output_data/City_Data.csv", index = False)

# %%
#Read CSV File
file_clean = "output_data/City_Data.csv"
weatherdf = pd.read_csv(file_clean)

# %%
#Plot Latitude vs. Temperature Plot 
latitude = weatherdf["Lat"]
maxtemp = weatherdf["Max Temp"]
plt.scatter(latitude, maxtemp)
plt.title("City Latiude vs. Max Temperature (05/08/2020)")
plt.ylabel("Max Temprature (F)")
plt.xlabel("Latitude")
plt.grid()

# %%
#Plot Latitude vs. Humidity Plot 
latitude = weatherdf["Lat"]
maxtemp = weatherdf["Humidity"]
plt.scatter(latitude, maxtemp)
plt.title("City Latiude vs. Humidity (05/08/2020)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

# %%
#Plot Latitude vs. Cloudiness Plot 
latitude = weatherdf["Lat"]
cloudiness = weatherdf["Cloudiness"]
plt.scatter(latitude, cloudiness)
plt.title("City Latiude vs. Cloudiness (05/08/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# %%
#Plot Latitude vs. Wind Speed Plot 
latitude = weatherdf["Lat"]
wind = weatherdf["Wind Speed"]
plt.scatter(latitude, wind)
plt.title("City Latiude vs. Wind Speed (05/08/2020)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()

# %%
#Northern Hemisphere (greater than or equal to 0 degrees latitude)
#Data Frame for Northern Hemsphere
north = weatherdf.loc[weatherdf["Lat"]>=0,:]

#Southern Hemisphere (less than 0 degrees latitude)
#Data Frame for Southern Hemsphere
south = weatherdf.loc[weatherdf["Lat"]<0,:]

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = north["Lat"]
y_values = north["Max Temp"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (1,40), fontsize=15, color="red")
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.7230202421197859

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = south["Lat"]
y_values = south["Max Temp"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (-50,80), fontsize=15, color="red")
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.49089690828513083

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = north["Lat"]
y_values = north["Humidity"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (1,1),fontsize=15, color="red")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.009894213529998247

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = south["Lat"]
y_values = south["Humidity"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (-50,25),fontsize=15, color="red")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.027188814251698834

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = north["Lat"]
y_values = north["Cloudiness"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (1,50),fontsize=15, color="red")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.022370470696452146

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = south["Lat"]
y_values = south["Cloudiness"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (-50,60),fontsize=15, color="red")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.0483494773477392

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = north["Lat"]
y_values = north["Wind Speed"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (30,22),fontsize=15, color="red")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.007175055606821195

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = south["Lat"]
y_values = south["Wind Speed"]

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y=" + str(round(slope, 2)) + "x +" + str(round(intercept, 2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r")
plt.annotate(line_eq, (-55,11),fontsize=15, color="red")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.008410563552816582
