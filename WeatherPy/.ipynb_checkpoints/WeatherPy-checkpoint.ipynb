# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from pprint import pprint

# %%
# Import API key
from api_keys import weather_api_key

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
country
# Out:
# ['BR',
#  'MG',
#  'AO',
#  'CL',
#  'SO',
#  'KI',
#  'PE',
#  'GB',
#  'NZ',
#  'US',
#  'BR',
#  'ZA',
#  'PF',
#  'AR',
#  'ZA',
#  'CA',
#  'CA',
#  'PF',
#  'ES',
#  'BY',
#  'US',
#  'AU',
#  'PG',
#  'US',
#  'JP',
#  'PG',
#  'NZ',
#  'RU',
#  'AU',
#  'IS',
#  'NZ',
#  'AU',
#  'US',
#  'US',
#  'JP',
#  'RU',
#  'CL',
#  'CL',
#  'IS',
#  'EC',
#  'VN',
#  'CA',
#  'AU',
#  'TO',
#  'AU',
#  'RU',
#  'RU',
#  'PE',
#  'ID',
#  'BY',
#  'RU',
#  'ZA',
#  'TC',
#  'GL',
#  'NU',
#  'US',
#  'US',
#  'RU',
#  'MX',
#  'IN',
#  'AU',
#  'US',
#  'UY',
#  'AU',
#  'RU',
#  'AU',
#  'SY',
#  'IN',
#  'AR',
#  'CK',
#  'JP',
#  'NZ',
#  'GL',
#  'IN',
#  'US',
#  'MU',
#  'JP',
#  'PE',
#  'RU',
#  'BR',
#  'RU',
#  'PH',
#  'FI',
#  'CN',
#  'PT',
#  'RU',
#  'GH',
#  'RU',
#  'HK',
#  'RU',
#  'US',
#  'GL',
#  'NZ',
#  'RU',
#  'ID',
#  'US',
#  'ZA',
#  'CA',
#  'SY',
#  'GL',
#  'TH',
#  'ID',
#  'SO',
#  'BR',
#  'VE',
#  'SS',
#  'ES',
#  'CA',
#  'PG',
#  'CL',
#  'UZ',
#  'US',
#  'RU',
#  'LY',
#  'CD',
#  'RU',
#  'SV',
#  'AR',
#  'GB',
#  'TD',
#  'ID',
#  'US',
#  'NC',
#  'CA',
#  'RU',
#  'FO',
#  'MX',
#  'AO',
#  'KI',
#  'MX',
#  'NE',
#  'RU',
#  'RU',
#  'US',
#  'AU',
#  'RU',
#  'ID',
#  'CA',
#  'AR',
#  'US',
#  'MG',
#  'RU',
#  'VN',
#  'CN',
#  'AU',
#  'MG',
#  'MY',
#  'RU',
#  'ZA',
#  'VU',
#  'BR',
#  'IN',
#  'GA',
#  'RU',
#  'CA',
#  'PG',
#  'BF',
#  'ET',
#  'AR',
#  'AR',
#  'RU',
#  'RU',
#  'PH',
#  'SB',
#  'ID',
#  'US',
#  'MV',
#  'BW',
#  'BR',
#  'VU',
#  'LR',
#  'US',
#  'RU',
#  'RU',
#  'IN',
#  'GL',
#  'VN',
#  'US',
#  'IN',
#  'MV',
#  'QA',
#  'US',
#  'SA',
#  'MA',
#  'MG',
#  'LK',
#  'US',
#  'MU',
#  'IN',
#  'CN',
#  'IN',
#  'MU',
#  'US',
#  'LK',
#  'GF',
#  'IS',
#  'CL',
#  'BR',
#  'SS',
#  'CN',
#  'ES',
#  'PK',
#  'CL',
#  'PT',
#  'NO',
#  'AU',
#  'GL',
#  'ZA',
#  'RU',
#  'TO',
#  'AU',
#  'IT',
#  'US',
#  'RE',
#  'RU',
#  'AU',
#  'RO',
#  'NG',
#  'BR',
#  'JP',
#  'PE',
#  'RU',
#  'NZ',
#  'US',
#  'US',
#  'RU',
#  'US',
#  'GB',
#  'DE',
#  'BR',
#  'AU',
#  'PT',
#  'BR',
#  'CD',
#  'MX',
#  'RU',
#  'US',
#  'AU',
#  'CN',
#  'RU',
#  'PH',
#  'IS',
#  'AU',
#  'CA',
#  'ZA',
#  'CA',
#  'GL',
#  'IR',
#  'CN',
#  'NE',
#  'BR',
#  'JP',
#  'CN',
#  'RU',
#  'ID',
#  'BR',
#  'KZ',
#  'BR',
#  'US',
#  'ZM',
#  'AI',
#  'ID',
#  'CD',
#  'MV',
#  'RU',
#  'RU',
#  'CA',
#  'BR',
#  'RU',
#  'PF',
#  'MG',
#  'RU',
#  'RU',
#  'ZM',
#  'AO',
#  'AU',
#  'NO',
#  'IN',
#  'PT',
#  'NZ',
#  'ZM',
#  'MX',
#  'IE',
#  'MX',
#  'CA',
#  'LR',
#  'BR',
#  'AU',
#  'HT',
#  'PT',
#  'RU',
#  'MX',
#  'PG',
#  'GA',
#  'RU',
#  'RO',
#  'RU',
#  'FR',
#  'AU',
#  'RO',
#  'MN',
#  'ZA',
#  'TL',
#  'PG',
#  'VN',
#  'US',
#  'CN',
#  'RU',
#  'CM',
#  'AU',
#  'CA',
#  'AU',
#  'LV',
#  'LK',
#  'RU',
#  'ID',
#  'CO',
#  'SD',
#  'CA',
#  'IE',
#  'ID',
#  'BF',
#  'RU',
#  'RU',
#  'US',
#  'SE',
#  'NA',
#  'BR',
#  'RE',
#  'AU',
#  'TR',
#  'CN',
#  'NZ',
#  'BW',
#  'CA',
#  'US',
#  'JP',
#  'BR',
#  'BR',
#  'US',
#  'AU',
#  'TM',
#  'RU',
#  'RU',
#  'MX',
#  'ZM',
#  'BS',
#  'SD',
#  'FI',
#  'US',
#  'MX',
#  'KE',
#  'CN',
#  'PE',
#  'US',
#  'PY',
#  'GD',
#  'CA',
#  'CG',
#  'NO',
#  'NO',
#  'US',
#  'IN',
#  'MU',
#  'CI',
#  'AF',
#  'AR',
#  'US',
#  'PT',
#  'TN',
#  'VN',
#  'BR',
#  'UZ',
#  'BF',
#  'CN',
#  'PH',
#  'BR',
#  'BR',
#  'RU',
#  'CN',
#  'GL',
#  'CN',
#  'GB',
#  'AU',
#  'ES',
#  'MG',
#  'CN',
#  'CD',
#  'CO',
#  'EC',
#  'UG',
#  'MN',
#  'RU',
#  'SE',
#  'BR',
#  'GB',
#  'BD',
#  'US',
#  'CO',
#  'US',
#  'RU',
#  'GL',
#  'MG',
#  'AU',
#  'PH',
#  'US',
#  'PT',
#  'AU',
#  'IN',
#  'MZ',
#  'AU',
#  'AF',
#  'PW',
#  'CN',
#  'NA',
#  'RU',
#  'US',
#  'KY',
#  'CI',
#  'MR',
#  'RU',
#  'AU',
#  'NP',
#  'BQ',
#  'IL',
#  'KZ',
#  'TH',
#  'RU',
#  'NE',
#  'AU',
#  'RU',
#  'US',
#  'RU',
#  'BB',
#  'AR',
#  'AW',
#  'GB',
#  'BR',
#  'MU',
#  'TZ',
#  'AR',
#  'CF',
#  'VE',
#  'US',
#  'ZA',
#  'CA',
#  'RU',
#  'IT',
#  'BR',
#  'BR',
#  'RU',
#  'JP',
#  'RU',
#  'PK',
#  'CZ',
#  'IN',
#  'ZA',
#  'RU',
#  'RU',
#  'RU',
#  'LR',
#  'AU',
#  'AU',
#  'BR',
#  'US',
#  'GE',
#  'RU',
#  'US',
#  'US',
#  'CV',
#  'CI',
#  'PH',
#  'YT',
#  'FO',
#  'IL',
#  'ES',
#  'US',
#  'AO',
#  'PY',
#  'UY',
#  'CN',
#  'VN',
#  'PT',
#  'ZM',
#  'IR',
#  'CA',
#  'AR',
#  'RU',
#  'UA',
#  'SN',
#  'ES',
#  'IN',
#  'IQ',
#  'GY',
#  'BR',
#  'RU',
#  'CA',
#  'US',
#  'GR',
#  'SJ',
#  'BR',
#  'GA',
#  'AU',
#  'CN',
#  'CA',
#  'ET',
#  'GL',
#  'RU',
#  'ZA',
#  'US',
#  'RU',
#  'MX',
#  'KE',
#  'SA',
#  'US',
#  'GH',
#  'RU',
#  'ID',
#  'TD',
#  'RU',
#  'PE',
#  'CN',
#  'US',
#  'AU',
#  'US',
#  'US',
#  'JP',
#  'RU',
#  'RU',
#  'JP',
#  'NG',
#  'PK',
#  'TR',
#  'PF',
#  'BR',
#  'BF',
#  'CA',
#  'SO',
#  'US',
#  'US',
#  'RU',
#  'ID',
#  'MR',
#  'CV',
#  'ZA',
#  'PH',
#  'AU',
#  'RU',
#  'PL',
#  'IR',
#  'RU',
#  'FI',
#  'UG',
#  'RU',
#  'BR',
#  'US',
#  'PL',
#  'US',
#  'RU',
#  'KE',
#  'LY',
#  'BW',
#  'BR',
#  'ES',
#  'ID',
#  'ID',
#  'ZA',
#  'AU',
#  'NE',
#  'ID',
#  'SD',
#  'GB',
#  'BR']

# %%
#Perform API Calls
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date_unix = []

#Perform a weather check on each city using a series of successive API calls.
url = "http://api.openweathermap.org/data/2.5/weather?"
for city in cities:
# Build query URL
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    # Get weather data
    weather_response = requests.get(query_url).json()
    try:
        city_name.append(weather_response["name"])
        lat.append(weather_response["coord"]["lat"])
        lng.append(weather_response["coord"]["lon"])
        max_temp.append(weather_response["main"]["temp_max"])
        humidity.append(weather_response["main"]["humidity"])
        cloudiness.append(weather_response["clouds"]["all"])
        wind_speed.append(weather_response["wind"]["speed"])
        country.append(weather_response["sys"]["country"])
        date_unix.append(weather_response["sys"]["sunrise"])  
    except:
        city_name.append("NaN")
        lat.append("NaN")
        lng.append("NaN")
        max_temp.append("NaN")
        humidity.append("NaN")
        cloudiness.append("NaN")
        wind_speed.append("NaN")
        country.append("NaN")
        date_unix.append("NaN")

country
# Out:
# ['ZM',
#  'RU',
#  'CO',
#  'US',
#  'NaN',
#  'US',
#  'CA',
#  'US',
#  'MX',
#  'SB',
#  'NZ',
#  'LK',
#  'AU',
#  'YE',
#  'NaN',
#  'NaN',
#  'PF',
#  'ZA',
#  'MG',
#  'MN',
#  'RU',
#  'CK',
#  'RU',
#  'NaN',
#  'NZ',
#  'RU',
#  'US',
#  'GL',
#  'CL',
#  'MX',
#  'NZ',
#  'NaN',
#  'AR',
#  'NZ',
#  'MX',
#  'BR',
#  'SE',
#  'NZ',
#  'BR',
#  'RU',
#  'GL',
#  'PT',
#  'UZ',
#  'PG',
#  'MT',
#  'NaN',
#  'MX',
#  'ZA',
#  'CA',
#  'TO',
#  'US',
#  'ES',
#  'AU',
#  'PT',
#  'CN',
#  'JP',
#  'IN',
#  'US',
#  'CA',
#  'US',
#  'GB',
#  'MU',
#  'PH',
#  'AU',
#  'JP',
#  'PT',
#  'ML',
#  'NaN',
#  'RU',
#  'US',
#  'CA',
#  'US',
#  'US',
#  'PE',
#  'NaN',
#  'ZA',
#  'KR',
#  'CD',
#  'CA',
#  'RU',
#  'RU',
#  'RU',
#  'RU',
#  'ZA',
#  'AU',
#  'NL',
#  'GL',
#  'AU',
#  'CO',
#  'MZ',
#  'AR',
#  'ML',
#  'BO',
#  'ZA',
#  'RU',
#  'NaN',
#  'RE',
#  'CD',
#  'ZA',
#  'RU',
#  'US',
#  'ES',
#  'EC',
#  'US',
#  'BR',
#  'RU',
#  'RU',
#  'LK',
#  'SA',
#  'RU',
#  'US',
#  'IN',
#  'TL',
#  'RU',
#  'NaN',
#  'BR',
#  'CL',
#  'PH',
#  'KZ',
#  'BR',
#  'PG',
#  'RU',
#  'BR',
#  'CA',
#  'HK',
#  'NO',
#  'MY',
#  'NaN',
#  'AU',
#  'US',
#  'NZ',
#  'NZ',
#  'BR',
#  'US',
#  'MZ',
#  'NaN',
#  'BR',
#  'CA',
#  'RU',
#  'IN',
#  'AU',
#  'CN',
#  'MU',
#  'BR',
#  'RU',
#  'CA',
#  'IN',
#  'PF',
#  'ID',
#  'GL',
#  'AO',
#  'RU',
#  'PT',
#  'CA',
#  'KZ',
#  'AU',
#  'AU',
#  'PR',
#  'SJ',
#  'US',
#  'ID',
#  'BR',
#  'CL',
#  'ID',
#  'RU',
#  'CL',
#  'NaN',
#  'AU',
#  'CL',
#  'FO',
#  'KZ',
#  'US',
#  'RU',
#  'BR',
#  'AU',
#  'EC',
#  'US',
#  'JP',
#  'CV',
#  'CN',
#  'NaN',
#  'GL',
#  'CA',
#  'AO',
#  'US',
#  'SO',
#  'RU',
#  'NaN',
#  'BR',
#  'RU',
#  'IN',
#  'BR',
#  'KI',
#  'AU',
#  'AU',
#  'US',
#  'AR',
#  'AU',
#  'RO',
#  'ET',
#  'RU',
#  'CA',
#  'NaN',
#  'ZA',
#  'CV',
#  'JP',
#  'MX',
#  'US',
#  'US',
#  'JP',
#  'US',
#  'FR',
#  'SR',
#  'CN',
#  'IL',
#  'NaN',
#  'CA',
#  'SO',
#  'CA',
#  'PF',
#  'GT',
#  'US',
#  'CA',
#  'BR',
#  'NO',
#  'MG',
#  'AR',
#  'CN',
#  'RU',
#  'CL',
#  'CA',
#  'LK',
#  'US',
#  'IN',
#  'SE',
#  'GL',
#  'US',
#  'CN',
#  'AU',
#  'IT',
#  'NaN',
#  'IR',
#  'AU',
#  'FI',
#  'MU',
#  'PH',
#  'SS',
#  'BR',
#  'SD',
#  'NaN',
#  'JP',
#  'CN',
#  'NZ',
#  'RU',
#  'MV',
#  'NO',
#  'KE',
#  'AU',
#  'CA',
#  'PE',
#  'NaN',
#  'RU',
#  'CN',
#  'PE',
#  'US',
#  'IS',
#  'US',
#  'DE',
#  'NaN',
#  'RU',
#  'JP',
#  'VU',
#  'GT',
#  'CL',
#  'SS',
#  'SO',
#  'VU',
#  'RU',
#  'ML',
#  'CN',
#  'ES',
#  'BR',
#  'CA',
#  'PY',
#  'US',
#  'IT',
#  'AR',
#  'GL',
#  'US',
#  'CN',
#  'RU',
#  'US',
#  'CN',
#  'GR',
#  'UY',
#  'NaN',
#  'NaN',
#  'CN',
#  'VU',
#  'GL',
#  'PT',
#  'US',
#  'US',
#  'US',
#  'RU',
#  'NaN',
#  'PG',
#  'NaN',
#  'PF',
#  'NZ',
#  'NA',
#  'ID',
#  'EE',
#  'ZM',
#  'AU',
#  'MY',
#  'RU',
#  'AO',
#  'CA',
#  'NO',
#  'LK',
#  'BR',
#  'SN',
#  'BR',
#  'GH',
#  'JP',
#  'CA',
#  'CD',
#  'CL',
#  'PY',
#  'MR',
#  'SA',
#  'IR',
#  'MG',
#  'BR',
#  'NaN',
#  'NG',
#  'RU',
#  'KR',
#  'BO',
#  'CL',
#  'MM',
#  'US',
#  'OM',
#  'US',
#  'FI',
#  'US',
#  'EG',
#  'RU',
#  'CN',
#  'MX',
#  'LR',
#  'IS',
#  'BR',
#  'LY',
#  'RU',
#  'ID',
#  'NO',
#  'JP',
#  'NA',
#  'KY',
#  'MX',
#  'MV',
#  'IN',
#  'RU',
#  'SY',
#  'NaN',
#  'IE',
#  'CO',
#  'SD',
#  'NE',
#  'RU',
#  'RU',
#  'RU',
#  'JM',
#  'GA',
#  'PT',
#  'US',
#  'RU',
#  'GW',
#  'PG',
#  'RU',
#  'NO',
#  'RU',
#  'PE',
#  'RU',
#  'NaN',
#  'JP',
#  'JP',
#  'RU',
#  'RU',
#  'GA',
#  'AU',
#  'NO',
#  'NaN',
#  'NaN',
#  'BR',
#  'AU',
#  'MY',
#  'CA',
#  'NaN',
#  'BR',
#  'TZ',
#  'IR',
#  'RU',
#  'GA',
#  'LK',
#  'ES',
#  'KE',
#  'AU',
#  'MX',
#  'ID',
#  'DZ',
#  'PH',
#  'PH',
#  'TD',
#  'BH',
#  'GF',
#  'CA',
#  'UA',
#  'GB',
#  'GL',
#  'SL',
#  'SD',
#  'BJ',
#  'BR',
#  'NA',
#  'CA',
#  'IN',
#  'CU',
#  'RU',
#  'MM',
#  'JP',
#  'PT',
#  'MG',
#  'NA',
#  'BR',
#  'NaN',
#  'CA',
#  'ID',
#  'CN',
#  'RU',
#  'NaN',
#  'CN',
#  'US',
#  'PT',
#  'SO',
#  'RU',
#  'IQ',
#  'IR',
#  'IT',
#  'NO',
#  'RE',
#  'US',
#  'NI',
#  'CO',
#  'PK',
#  'BR',
#  'IN',
#  'RU',
#  'NaN',
#  'CN',
#  'CL',
#  'US',
#  'NaN',
#  'NaN',
#  'CA',
#  'GB',
#  'CN',
#  'NaN',
#  'NI',
#  'ML',
#  'MG',
#  'GB',
#  'CN',
#  'RU',
#  'BB',
#  'RU',
#  'BR',
#  'NaN',
#  'ID',
#  'GB',
#  'CA',
#  'BR',
#  'NaN',
#  'RU',
#  'BR',
#  'US',
#  'GA',
#  'IS',
#  'AU',
#  'NO',
#  'IN',
#  'FI',
#  'GB',
#  'SY',
#  'NO',
#  'IN',
#  'NC',
#  'GT',
#  'CN',
#  'CG',
#  'AR',
#  'RU',
#  'IN',
#  'RU',
#  'ZA',
#  'NG',
#  'CA',
#  'US',
#  'NaN',
#  'MG',
#  'NE',
#  'JP',
#  'NZ',
#  'SS',
#  'NE',
#  'IN',
#  'ZA',
#  'ES',
#  'IT',
#  'CA',
#  'US',
#  'MM',
#  'RU',
#  'NaN',
#  'ID',
#  'NaN',
#  'US',
#  'BR',
#  'IR',
#  'UG',
#  'LY',
#  'PE',
#  'NA',
#  'BR',
#  'BR',
#  'UA',
#  'CN',
#  'PE',
#  'BR',
#  'TO',
#  'RU',
#  'BR',
#  'AR',
#  'MX',
#  'BR',
#  'CN',
#  'NaN',
#  'PE',
#  'JP',
#  'BR',
#  'US',
#  'RU',
#  'NaN',
#  'AO',
#  'CN',
#  'WS',
#  'RU',
#  'RU',
#  'BR',
#  'US',
#  'KI',
#  'CH',
#  'PG',
#  'AU',
#  'US',
#  'CO',
#  'NC',
#  'US',
#  'TR',
#  'IN',
#  'MX',
#  'FR',
#  'CN',
#  'NaN',
#  'GF',
#  'US',
#  'MU',
#  'GB',
#  'RU',
#  'RU',
#  'RU',
#  'MU',
#  'TH',
#  'SA',
#  'AZ',
#  'US',
#  'IS',
#  'ID',
#  'US',
#  'BR',
#  'US',
#  'RU',
#  'JP',
#  'NaN',
#  'GB',
#  'AU',
#  'ID',
#  'UA',
#  'PT',
#  'UG',
#  'CN',
#  'US',
#  'CN',
#  'ID',
#  'US',
#  'KG',
#  'CI',
#  'GT',
#  'RU',
#  'PG',
#  'PF',
#  'MY',
#  'RU',
#  'CM',
#  'EG']

# %% [markdown]
# #Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
len(country)
# Out:
# 617

# %%
weather = pd.DataFrame({"City": city_name, "Lat": lat, "Lng" : lng, "Max Temp": max_temp, "Humidity": humidity,
                           "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Country": country, "Date": date_unix})
weather
# Out:
#             City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0      Mporokoso  -9.37   30.12   288.69       86         66       3.24
# 1      Saskylakh  71.92  114.08   256.88       93         70       1.84
# 2         Juradó   7.11  -77.76   300.98       83        100       1.99
# 3          Sitka  57.05 -135.33   288.15       47         90        2.1
# 4            NaN    NaN     NaN      NaN      NaN        NaN        NaN
# ..           ...    ...     ...      ...      ...        ...        ...
# 612         Fare  -16.7 -151.02   301.23       76         97       5.29
# 613        Lumut   4.23  100.63   300.15       94         20          1
# 614      Kirensk  57.79  108.11   277.84       59          1        0.5
# 615  Nanga Eboko   4.68   12.37   294.18       97         90       0.96
# 616     Hurghada  27.26   33.81   297.15       27          0       6.26
#
#     Country        Date
# 0        ZM  1588997060
# 1        RU           0
# 2        CO  1588935307
# 3        US  1588942526
# 4       NaN         NaN
# ..      ...         ...
# 612      PF  1588954703
# 613      MY  1588979108
# 614      RU  1588970225
# 615      CM  1588913862
# 616      EG  1588993196
#
# [617 rows x 9 columns]

# %%
#Print CSV with df
weather.to_csv("output_data/cities.csv", index = False)

# %%
#Read CSV File
file = "output_data/cities.csv"
weather_df = pd.read_csv(file)

weather_clean = weather_df.dropna(how="all")

weather_clean
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Mporokoso  -9.37   30.12    288.69      86.0        66.0        3.24
# 1      Saskylakh  71.92  114.08    256.88      93.0        70.0        1.84
# 2         Juradó   7.11  -77.76    300.98      83.0       100.0        1.99
# 3          Sitka  57.05 -135.33    288.15      47.0        90.0        2.10
# 5         Bethel  41.37  -73.41    279.26      87.0        90.0        3.12
# ..           ...    ...     ...       ...       ...         ...         ...
# 612         Fare -16.70 -151.02    301.23      76.0        97.0        5.29
# 613        Lumut   4.23  100.63    300.15      94.0        20.0        1.00
# 614      Kirensk  57.79  108.11    277.84      59.0         1.0        0.50
# 615  Nanga Eboko   4.68   12.37    294.18      97.0        90.0        0.96
# 616     Hurghada  27.26   33.81    297.15      27.0         0.0        6.26
#
#     Country          Date
# 0        ZM  1.588997e+09
# 1        RU  0.000000e+00
# 2        CO  1.588935e+09
# 3        US  1.588943e+09
# 5        US  1.588931e+09
# ..      ...           ...
# 612      PF  1.588955e+09
# 613      MY  1.588979e+09
# 614      RU  1.588970e+09
# 615      CM  1.588914e+09
# 616      EG  1.588993e+09
#
# [571 rows x 9 columns]

# %% [markdown]
# weather_clean.count()

# %%
#Inspect the data and remove the cities where the humidity > 100%.
weather_clean.loc[weather_clean["Humidity"]>100, :]

#Skipped this step because there are no cities that have humidity > 100%.
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#Print CSV with df
weather_clean.to_csv("output_data/City_Data.csv", index = False)

# %%
#Plot Latitude vs. Temperature Plot
