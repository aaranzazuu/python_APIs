# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
#from  import g_key

# %% [markdown]
# API KEY FROM GITIGNORE

# %%
#Load the csv exported in Part I to a DataFrame

#Read CSV File
output_file = "../WeatherPy/output_data/City_Data.csv"
weather = pd.read_csv(output_file)
weather
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Mataura -46.19  168.86     59.83      62.0         0.0
# 1              Vaini -21.20 -175.20     82.40      83.0        75.0
# 2            Ahipara -35.17  173.17     65.41      63.0         0.0
# 3             Xining  36.62  101.77     38.32      74.0        92.0
# 4    Severo-Kuril'sk  50.68  156.12     34.47      88.0        83.0
# ..               ...    ...     ...       ...       ...         ...
# 536           Ixtapa  20.70 -105.20     80.60      83.0         5.0
# 537       Nouadhibou  20.93  -17.03     66.20      82.0        13.0
# 538            Simao  22.79  100.97     74.55      67.0         0.0
# 539           Samaná  19.21  -69.34     78.48      82.0        17.0
# 540            Tāndā  26.55   82.65     83.16      27.0         0.0
#
#      Wind Speed Country          Date
# 0          3.47      NZ  1.588968e+09
# 1         16.11      TO  1.589047e+09
# ...

# %%
#Humidity Heatmap

gmaps.configure(api_key = "AIzaSyAJZlKxLzXtkN8obJKH1cTM--S96ZrbY94")
locations = weather[["Lat", "Lng"]]
hum = weather["Humidity"]

#Plot Gmaps
fig = gmaps.figure()

#Create a heat layer
fig.add_layer(gmaps.heatmap_layer(locations, weights = hum, max_intensity=100))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create new DataFrame fitting weather criteria

#Wind speed less than 10 mph.
#Cloudinss of less than 20%
#Max temp of lower than 100 degrees but higher than 75.


ideal_weather = weather.loc[(weather["Wind Speed"]<10)&(weather["Cloudiness"]<20)&(weather["Max Temp"]>70)]
ideal_weather


#Drop any rows will null value
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 41        Porbandar  21.64   69.61     80.02      84.0         0.0
# 57         Taunggyi  20.78   97.03     74.07      53.0         0.0
# 62             Susa  32.19   48.24     75.74      29.0         2.0
# 63     San Patricio  19.22 -104.70     80.60      69.0         5.0
# 90            Tabuk  17.42  121.44     86.41      64.0        17.0
# 143       Abu Dhabi  24.47   54.37     82.00      69.0         0.0
# 164      Saddiqabad  28.31   70.13     87.33      24.0         0.0
# 166         Kavieng  -2.57  150.80     85.80      69.0         0.0
# 180       Namatanai  -3.67  152.43     86.74      65.0         0.0
# 196    Saint George  37.10 -113.58     89.60       6.0         1.0
# 199             Sur  22.57   59.53     88.02      45.0         0.0
# 223         Verāval  20.90   70.37     80.78      83.0         0.0
# 233          Lompoc  34.64 -120.46     75.00      63.0         1.0
# ...

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
response_list = []

for index,row in ideal_weather.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    locations_ideal = (f"{lat},{lng}")
    #location = row["City"]
    
    #add key to params
    params = {
    "type": "lodging",
    "keyword": "hotel",
    "radius": 5000,
    "key": "AIzaSyAJZlKxLzXtkN8obJKH1cTM--S96ZrbY94",
    "location": locations_ideal
    }

    response = requests.get(base_url, params=params).json()
    response_list.append(response)
    pprint(response)
pprint(response_list)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAAIw-uOiDtiHDDAMZ3ME5f3QOfRlZaJUGH-vL9q3WGhm7pWQgrik79nIIxeB_XZ_mbLO6HKE3JjyCUL26aCDl2Ut-mb_kbD4gNrP5tZNKBO7IGz1O873GTjBwbPAfCEbbrlW0yPvSL_v-opd73lVhT-ZNgAy-QLv-zK3v9LyVg_2Zl4r-WEw_wTuypGDaopC_zCThLwVmziyfQIn8Jh22HG2Sa0OMmWz1o6ZHyHXs8iZnkmMcrvAI-tBHFvVGsNyEA5x2-9XLzdb0Ua3EIdYsPao-2PQLCcRzzTx5rcvo90xoaoGy0OMDyOTecWJeszN6bTR2AodmxffuhzsaFN5APDgGZT5i7su3-EcDSfKFMU2vRUgLLqyOTFeeyokNmr5pNk1dEMb4KuVMKVjE6Y3SnwESEPviHJQO6ED-Rdf_CCpbsnIaFMvrh5mO80r67V0TR55keqhJnM3r',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 21.6297793, 'lng': 69.6134122},
#                            'viewport': {'northeast': {'lat': 21.63112912989272,
#                                                       'lng': 69.61476202989272},
#                                         'southwest': {'lat': 21.62842947010728,
#                                                       'lng': 69.61206237010728}}},
# ...

# %%
hotel_name = []
hotel_lat = []
hotel_lng = []

for x in range(59):
    try:
        hotel_name.append(response_list[x]["results"][0]["name"])
        hotel_lat.append(response_list[x]["results"][0]["geometry"]["location"]["lat"])
        hotel_lng.append(response_list[x]["results"][0]["geometry"]["location"]["lng"])       
    except:
        hotel_name.append("NaN")
        #hotel_city.append("NaN")
len(hotel_name)
#hotel_lat,2
# Out:
# 59

# %%
hotel_city_clean = []

for item in hotel_city:
    res = item.split(",") 
    hotel_city_clean.append(res)
    
hotel_city_clean
# Out:
# [['JJQ4+GM Porbandar', ' Gujarat', ' India'],
#  ['Q2Q8+G9 Taunggyi', ' Myanmar (Burma)'],
#  ['56VV+PR Shush', ' Khuzestan Province', ' Iran'],
#  ['6838+C9 Barra de Navidad', ' Jalisco', ' Mexico'],
#  ['CF72+HV Tabuk', ' Kalinga', ' Philippines'],
#  ['G929+79 Abu Dhabi - United Arab Emirates'],
#  ['73WR+P5 Sadiqabad', ' Pakistan'],
#  ['CQ8J+XG Kavieng', ' Papua New Guinea'],
#  ['8CPR+H4 Namatanai', ' Papua New Guinea'],
#  ['3CH8+9X St. George', ' Utah'],
#  ['HF8W+H8 Sur', ' Oman'],
#  ['VCX5+V2 Somnath', ' Gujarat', ' India'],
#  ['MG4R+9G Lompoc', ' California'],
#  ['9RXJ+GM Kalmunai', ' Sri Lanka'],
#  ['2FQM+F6 Walvis Bay', ' Namibia'],
#  ['QQRC+WX Letpadan', ' Myanmar (Burma)'],
#  ['HP3J+V6 Jatiwangi', ' Bima', ' West Nusa Tenggara', ' Indonesia'],
#  ['GXW3+GC Marsh Harbour', ' Bahamas'],
#  ['6MHX+M4 Auki', ' Solomon Islands'],
#  ['326F+X4 Centro', ' Russas - State of Ceará', ' Brazil'],
#  ['G2J3+2F Aqaba', ' Jordan'],
#  ['CJF2+2X Elk Grove', ' California'],
# ...
